# %% [markdown]
# <a href="https://colab.research.google.com/github/subu604/gen-ai/blob/main/agenticai_youtubescriptgenerator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q openai-agents

# %%
from agents import Agent, Runner

# %%
from google.colab import userdata
import os
from agents import Agent, Runner, RunConfig, OpenAIProvider, WebSearchTool

# Ensure the API key is available
OPENAI_API_KEY = userdata.get('OPENAI_API_KEY')
os.environ["OPENAI_API_KEY"] = OPENAI_API_KEY

# %%
from pydantic import BaseModel

class VideoScript(BaseModel):
    outline: str
    script: str

# %%
video_script_creator = Agent(
    name="Video script creator",
    model="gpt-4o-mini",
    handoff_description="Used for generating a youtube video script based on an topic outline.",
    instructions=(
        "Given a topic and an outline, your job is to generate script for creating youtube video for each section of the outline."
        "Format the script is in Markdown using a mix of text for explanation and code snippets for examples if it is coding topic."
        "make sure video script is informative, interesting and engaging"
    ),
    output_type=VideoScript
)

# %%
outline_builder = Agent(
    name="Outline Builder",
    model="gpt-4o-mini",
    instructions=(
        "Given a particular topic, your job is to help come up with a outline for a youtube video. You will do that by crafting an outline."
        "After making the outline, hand it to the video script creator agent."
    ),
    handoffs=[video_script_creator]
)

# %%
script_response = await Runner.run(outline_builder, "Model context protocol in Agentic AI")
print(script_response.final_output)
# Out:
# outline='1. Introduction to Agentic AI  \n2. Importance of Model Context Protocol  \n3. How Model Context Protocol Works  \n4. Applications of Model Context Protocol  \n5. Challenges and Considerations  \n6. Future of Model Context Protocol in AI  \n7. Conclusion' script='# Video Script: Model Context Protocol in Agentic AI\n\n## 1. Introduction to Agentic AI  \nWelcome back, everyone! Today, we’re diving into the fascinating world of Agentic AI and exploring a key component – the Model Context Protocol. \n\nAgentic AI refers to artificial intelligence systems that can act autonomously, make decisions, and adapt based on their environment. \n\nBut what exactly is the Model Context Protocol? Let’s uncover its significance in shaping intelligent agents.\n\n---\n\n## 2. Importance of Model Context Protocol  \nSo, why is the Model Context Protocol critical in Agentic AI?  \n\nImagine you’re in a foreign city without a map. You’d need a way to understand your surroundings before making decisions. \n\nThe Model Context Protocol is like that map. It provides context, allows agents to interpret data, and helps them make informed decisions based on their environment.\n\n---\n\n## 3. How Model Context Protocol Works  \nNow, let’s break down how the Model Context Protocol operates.  \n\nAt its core, it involves:  \n1. **Data Collection**: Agents gather data from their environment, like user inputs or sensor readings.  \n2. **Contextual Analysis**: The protocol analyzes this data to extract meaningful information.  \n3. **Model Adaptation**: Based on the insights, the agent adapts its model to achieve desired outcomes.  \n\nFor example, if an AI-driven robot is in a room, it will collect data from the surroundings – such as objects and people – to enhance its navigation.\n\n### Code Example: Contextual Analysis\n```python\nclass ContextualAgent:\n    def __init__(self, environment_data):\n        self.environment_data = environment_data\n        self.context = self.analyze_context()  \n\n    def analyze_context(self):\n        # Simple contextual analysis  \n        return {"objects": [obj for obj in self.environment_data if obj.is_visible()]}\n```\nThis code snippet defines a simple agent that analyzes its environment by filtering visible objects.\n\n---\n\n## 4. Applications of Model Context Protocol  \nThe applications of the Model Context Protocol are vast!  \n\n1. **Autonomous Vehicles**: Help them understand road conditions, traffic signals, and pedestrian movements.\n2. **Smart Assistants**: Improve responsiveness based on user queries and preferences.\n3. **Robotics**: Enable robots to interact effectively in dynamic environments, enhancing safety and efficiency.\n\n---\n\n## 5. Challenges and Considerations  \nHowever, implementing this protocol isn’t without its challenges.  \n\n1. **Data Overload**: Agents can become overwhelmed with excessive data, leading to indecision.\n2. **Bias in Data**: If the gathered data is biased, the agent’s decisions will also be biased, causing ethical concerns.\n3. **Complexity of Context**: Real-world contexts can be highly complex and nuanced, making it difficult for agents to interpret accurately.\n\n---\n\n## 6. Future of Model Context Protocol in AI  \nSo, what does the future hold for the Model Context Protocol in AI?  \n\nAs AI continues to evolve, we’ll see advancements in machine learning algorithms that can better handle context.  \n\nThere’s also potential for improved collaboration between agents, allowing them to share contextual information and learn from one another, leading to smarter and more efficient systems.\n\n---\n\n## 7. Conclusion  \nIn conclusion, the Model Context Protocol is a fundamental building block for making Agentic AI more intelligent and responsive.  \n\nAs we enhance this technology, we take significant strides toward creating autonomous systems that can navigate our complex world.\n\nThanks for watching! If you enjoyed this video, please give it a thumbs up an ...

# %%
from IPython.display import Markdown, display
display(Markdown(script_response.final_output.script))
# Out:
# # Video Script: Model Context Protocol in Agentic AI
#
# ## 1. Introduction to Agentic AI
# Welcome back, everyone! Today, we’re diving into the fascinating world of Agentic AI and exploring a key component – the Model Context Protocol.
#
# Agentic AI refers to artificial intelligence systems that can act autonomously, make decisions, and adapt based on their environment.
#
# But what exactly is the Model Context Protocol? Let’s uncover its significance in shaping intelligent agents.
#
# ---
#
# ## 2. Importance of Model Context Protocol
# So, why is the Model Context Protocol critical in Agentic AI?
#
# Imagine you’re in a foreign city without a map. You’d need a way to understand your surroundings before making decisions.
#
# The Model Context Protocol is like that map. It provides context, allows agents to interpret data, and helps them make informed decisions based on their environment.
#
# ---
#
# ## 3. How Model Context Protocol Works
# Now, let’s break down how the Model Context Protocol operates.
#
# At its core, it involves:
# 1. **Data Collection**: Agents gather data from their environment, like user inputs or sensor readings.
# 2. **Contextual Analysis**: The protocol analyzes this data to extract meaningful information.
# 3. **Model Adaptation**: Based on the insights, the agent adapts its model to achieve desired outcomes.
#
# For example, if an AI-driven robot is in a room, it will collect data from the surroundings – such as objects and people – to enhance its navigation.
#
# ### Code Example: Contextual Analysis
# ```python
# class ContextualAgent:
#     def __init__(self, environment_data):
#         self.environment_data = environment_data
#         self.context = self.analyze_context()
#
#     def analyze_context(self):
#         # Simple contextual analysis
#         return {"objects": [obj for obj in self.environment_data if obj.is_visible()]}
# ```
# This code snippet defines a simple agent that analyzes its environment by filtering visible objects.
#
# ---
#
# ## 4. Applications of Model Context Protocol
# The applications of the Model Context Protocol are vast!
#
# 1. **Autonomous Vehicles**: Help them understand road conditions, traffic signals, and pedestrian movements.
# 2. **Smart Assistants**: Improve responsiveness based on user queries and preferences.
# 3. **Robotics**: Enable robots to interact effectively in dynamic environments, enhancing safety and efficiency.
#
# ---
#
# ## 5. Challenges and Considerations
# However, implementing this protocol isn’t without its challenges.
#
# 1. **Data Overload**: Agents can become overwhelmed with excessive data, leading to indecision.
# 2. **Bias in Data**: If the gathered data is biased, the agent’s decisions will also be biased, causing ethical concerns.
# 3. **Complexity of Context**: Real-world contexts can be highly complex and nuanced, making it difficult for agents to interpret accurately.
#
# ---
#
# ## 6. Future of Model Context Protocol in AI
# So, what does the future hold for the Model Context Protocol in AI?
#
# As AI continues to evolve, we’ll see advancements in machine learning algorithms that can better handle context.
#
# There’s also potential for improved collaboration between agents, allowing them to share contextual information and learn from one another, leading to smarter and more efficient systems.
#
# ---
#
# ## 7. Conclusion
# In conclusion, the Model Context Protocol is a fundamental building block for making Agentic AI more intelligent and responsive.
#
# As we enhance this technology, we take significant strides toward creating autonomous systems that can navigate our complex world.
#
# Thanks for watching! If you enjoyed this video, please give it a thumbs up and subscribe for more insights into the world of AI. See you next time!
